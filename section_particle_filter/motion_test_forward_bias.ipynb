# %%
import sys 
sys.path.append('../scripts/')
from robot import *

# %%
world = World(40.0, 0.1)      ###motion_test_forward_bias

initial_pose = np.array([0, 0, 0]).T
robots = []

for i in range(20):
    r = Robot(initial_pose, sensor=None, agent=Agent(0.1, 0.0))  #ここで生成されるロボットは異なるバイアスを持つ
    world.append(r)
    robots.append(r)

world.draw()
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
import pandas as pd ###motion_test_stats_bias
poses = pd.DataFrame([ [math.sqrt(r.pose[0]**2 + r.pose[1]**2), r.pose[2]] for r in robots], columns=['r', 'theta'])
poses.transpose()
# Out:
#               0         1         2         3         4        5         6  \
# r      4.034743  4.747710  4.644086  3.966744  3.275500  4.51810  4.097373
# theta -0.010980 -0.297796 -0.350212  0.125112  0.020266 -0.09538  0.296957
#
#               7         8         9        10        11        12        13  \
# r      4.355435  3.852678  3.448592  3.688871  3.863316  3.606627  3.549542
# theta  0.120844 -0.072234  0.356153 -0.029208  0.379432 -0.072578  0.478144
#
#              14        15        16        17        18        19
# r      4.259604  3.948791  4.011937  4.552118  4.377176  4.133548
# theta -0.260875  0.330121 -0.316027  0.353611  0.139446 -0.251511

# %%
print(poses["r"].var()) 
print(poses["r"].mean())
math.sqrt(poses["r"].var()/poses["r"].mean())
# Out:
# 0.16820412686132075
# 4.04662453643142
# 0.20387870586613843
