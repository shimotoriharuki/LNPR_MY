# %%
import sys     ###motion_test_header
sys.path.append('../scripts/')
from robot import *

# %%
world = World(40.0, 0.1)  

initial_pose = np.array([0, 0, 0]).T
robots = []

for i in range(20):
    r = Robot(initial_pose, sensor=None, agent=Agent(0.0, 0.1)) 
    world.append(r)
    robots.append(r)

world.draw()
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
import pandas as pd ###motion_test_stats_rot
poses = pd.DataFrame([ [math.sqrt(r.pose[0]**2 + r.pose[1]**2), r.pose[2]] for r in robots], columns=['r', 'theta'])
poses.transpose()
# Out:
#               0         1         2         3         4         5         6  \
# r      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# theta  3.759074  4.276619  4.690306  4.453986  4.237556  4.154548  3.605701
#
#               7         8         9        10        11        12        13  \
# r      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# theta  3.673686  3.930045  4.509452  4.093744  3.577055  3.875807  3.713776
#
#             14        15        16        17        18        19
# r      0.00000  0.000000  0.000000  0.000000  0.000000  0.000000
# theta  4.37199  4.227848  3.779666  4.130269  3.669879  3.835273

# %%
print(poses["theta"].var())
print(poses["theta"].mean())
math.sqrt(poses["theta"].var()/poses["theta"].mean())
# Out:
# 0.10972647692349988
# 4.028314033773424
# 0.16504184042460024
